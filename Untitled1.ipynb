# %%
import PyWaMG as wp
import datetime as dt

# %%
now = dt.datetime.now()

# %%
import pandas as pd

# %%
dataset = pd.read_csv("whatsapp dataset.csv")

# %%
dataset
# Out:
#                                                 Authors  \
# 0                        Naaz R., Saxena A.K., Ather D.
# 1                                Bonvin P.V., Romo V.O.
# 2     Kurniawan D.E., Iqbal M., Friadi J., Borman R....
# 3                            [No author name available]
# 4                               Tenggono A., Fariadi N.
# ...                                                 ...
# 1490  Aucinas A., Vallina-Rodriguez N., Grunenberger...
# 1491          Francesquini E., Goldman A., Mehaut J.-F.
# 1492  Abanmy N.O., Al-Quait N.A., Alami A.H., Al-Juh...
# 1493                 Nikou S., Bouwman H., de Reuver M.
# 1494                 Nikou S., Bouwman H., De Reuver M.
#
#                                            Author(s) ID  \
# 0                  54420834200;57210371558;55783082700;
# 1                              57215695908;57215697707;
# 2     57200983756;57214790147;57214106375;5720561532...
# 3                              [No author id available]
# ...

# %%
num = dataset['']

# %%
number="+918866663221"
# fpath="D:/ARTH/SummerInternship2021/task6/Face Recognition/img.jpg"

# %%
# !pip install pywhatBapi -y
# Out:
# Usage:
#   pip install [options] <requirement specifier> [package-index-options] ...
#   pip install [options] -r <requirements file> [package-index-options] ...
#   pip install [options] [-e] <vcs project url> ...
#   pip install [options] [-e] <local project path> ...
#   pip install [options] <archive url/path> ...
#
# no such option: -y

# %%
import os

# %%
os.system("pip install pywhatBapi")
# Out:
# 1
